# %%
from matplotlib import pylab
import pandas as pd
import numpy as np

# %%
#  trying to get the data from the dataset and trying to plot it but didn't went the way I thought it would go
# so I am commenting it out for now

# df = pd.read_csv("winequality-red.csv")

# %%
# from the large dataset just taking out data from two of the column

# x_acidity = df['fixed acidity']
# y_quality = df['alcohol']

# %%
# plotting it using matplotlib and using the color red as the third argument

# pylab.plot(x_acidity,y_quality,'r')

# %%
# the numpy function linspace is used for generating the data as random ig
# first 2 arguments are the number between and 3rd argument is the number of data
# here x is the numbpy array 

x = np.linspace(0,100, 50)

# as well as the y also is the numpy array
y = x**3+5

# %%
pylab.plot(x,y,'g')

# %%
# The concept of sub-plot 
# Here the pylab object is the whole canvas which is used for drawing a single graph
# The pylab canvas can be used for drawing many graphs for comparison 
# For ex: a graph may be pylab.plot(x,y) and another may be paylab.plot(y,x)
# For these 2 graphs to be at the same canvas or say side to side 
# We can use the sub plots as below

# The arguments are in the order of (rows, columns, index)

pylab.subplot(1,2,1)
pylab.plot(x,y,'r')

# we have to play with the numbers in the subplot argument to get used to them.

pylab.subplot(1,2,2)
pylab.plot(y,x,'g')

# %%
# till now we have used the module named pylab for drawing the graphs
# pylab module is deprecated in the year 2018 so it is no longer supported
# so now we will be learning pyplot for plotting the graph

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x1 = np.linspace(0,100,50)
x2 = np.array([100,2,3])
y1 = x1**2+8
y2 = x2**2+8

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.title("Basic data")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
# we can use different types of style for the graphs
# one of the most popular style is ggplot
#  here is how it's use

import matplotlib.pyplot as plt
# importing the module
from matplotlib import style

# mentioning which style to use
# more can be found at https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

style.use("ggplot")

# %%
# setting the data
x = np.linspace(0,10,2)
y = x**2

# %%
plt.plot(x,y)

# %%
#  using seaborn style
style.use("seaborn-v0_8")
# setting the data
x = np.linspace(0,10,2)
y = x**2

plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/matplotlib/style/core.py:127, in use(style)
#     126 try:
# --> 127     rc = rc_params_from_file(style, use_default_template=False)
#     128     _apply_style(rc)
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:856, in rc_params_from_file(fname, fail_on_error, use_default_template)
#     842 """
#     843 Construct a `RcParams` from file *fname*.
#     844
#    (...)
#     854     parameters specified in the file. (Useful for updating dicts.)
#     855 """
# --> 856 config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     858 if not use_default_template:
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:782, in _rc_params_in_file(fname, transform, fail_on_error)
#     781 rc_temp = {}
# --> 782 with _open_file_or_url(fname) as fd:
#     783     try:
#
# File /usr/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:759, in _open_file_or_url(fname)
#     758     encoding = "utf-8"
# --> 759 with open(fname, encoding=encoding) as f:
#     760     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn-v0_8'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 2
#       1 #  using seaborn style
# ----> 2 style.use("seaborn-v0_8")
#       3 # setting the data
#       4 x = np.linspace(0,10,2)
#
# File /usr/lib/python3/dist-packages/matplotlib/style/core.py:130, in use(style)
#     128     _apply_style(rc)
#     129 except IOError as err:
# --> 130     raise IOError(
#     131         "{!r} not found in the style library and input is not a "
#     132         "valid URL or path; see `style.available` for list of "
#     133         "available styles".format(style)) from err
#
# OSError: 'seaborn-v0_8' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
# Plotting 2 graphs and using legend
x1  = np.linspace(0,10,5)
y1 = x1**2
x2 = np.array([1,2,3,4])
y2 = x2**2

plt.plot(x1,y1,label="auto")
plt.plot(x2,y2,label="manual")

# for making the legend of the graph
plt.legend()

# %%
# using linewidth -> changing the width of the graph
# Plotting 2 graphs and using legend
x1  = np.linspace(0,10,5)
y1 = x1**2
x2 = np.array([1,2,3,4])
y2 = x2**2

plt.plot(x1,y1,label="auto",linewidth = 2)
plt.plot(x2,y2,label="manual",linewidth = 4)

# for making the legend of the graph
plt.legend()

# %%
# plotting other type of graphs
# first scatter plot
plt.scatter(x1,y1,label="auto",linewidth = 2)
plt.scatter(x2,y2,label="manual",linewidth = 4)

# %%
# Second histrogram plot
plt.hist(x1,y1,label="auto",linewidth = 2)
plt.hist(x2,y2,label="manual",linewidth = 4)

#  -> caution be sure the data you are using align with the data required by the histogram
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Second histrogram plot
#       2 plt.hist(x1,y1,label="auto",linewidth = 2)
# ----> 3 plt.hist(x2,y2,label="manual",linewidth = 4)
#       5 #  -> caution be sure the data you are using align with the data required by the histogram
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2590, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2584 @_copy_docstring_and_deprecators(Axes.hist)
#    2585 def hist(
#    2586         x, bins=None, range=None, density=False, weights=None,
#    2587         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2588         orientation='vertical', rwidth=None, log=False, color=None,
#    2589         label=None, stacked=False, *, data=None, **kwargs):
# -> 2590     return gca().hist(
#    2591         x, bins=bins, range=range, density=density, weights=weights,
#    2592         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2593         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2594         color=color, label=label, stacked=stacked,
#    2595         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:1416, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1413 @functools.wraps(func)
#    1414 def inner(ax, *args, data=None, **kwargs):
#    1415     if data is None:
# -> 1416         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1418     bound = new_sig.bind(ax, *args, **kwargs)
#    1419     auto_label = (bound.arguments.get(label_namer)
#    1420                   or bound.kwargs.get(label_namer))
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:6639, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6635 # Loop through datasets
#    6636 for i in range(nx):
#    6637     # this will automatically overwrite bins,
#    6638     # so that each histogram uses the same bins
# -> 6639     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6640     tops.append(m)
#    6641 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File <__array_function__ internals>:5, in histogram(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/numpy/lib/histograms.py:793, in histogram(a, bins, range, normed, weights, density)
#     681 r"""
#     682 Compute the histogram of a dataset.
#     683
#    (...)
#     789
#     790 """
#     791 a, weights = _ravel_and_check_weights(a, weights)
# --> 793 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     795 # Histogram is an integer or a float array depending on the weights.
#     796 if weights is None:
#
# File /usr/lib/python3/dist-packages/numpy/lib/histograms.py:431, in _get_bin_edges(a, bins, range, weights)
#     429     bin_edges = np.asarray(bins)
#     430     if np.any(bin_edges[:-1] > bin_edges[1:]):
# --> 431         raise ValueError(
#     432             '`bins` must increase monotonically, when an array')
#     434 else:
#     435     raise ValueError('`bins` must be 1d, when an array')
#
# ValueError: `bins` must increase monotonically, when an array

# %%
# third histogram 2d plot
plt.hist2d(x1,y1,label="auto",linewidth = 2)
plt.hist2d(x2,y2,label="manual",linewidth = 4)

# %%
# Fourth boxplot 2d plot
plt.boxplot(x1)

# -> more can be found at the documentaton of the matplotlib
